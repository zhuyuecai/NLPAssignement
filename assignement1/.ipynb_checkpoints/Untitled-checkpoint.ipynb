# %%
import pandas as pd
import numpy as np
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict
from nltk.corpus import wordnet as wn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import model_selection, naive_bayes, svm
from sklearn.metrics import accuracy_score

np.random.seed(500)

# %%
def getData(file_path):
    """
    @param: file_path, str, path to the data file
    @return: an np array with each element as a line in the file
    """
    with open(file_path) as f:
        lines=f.readlines()          
        dd = np.array(lines)
    return dd

def getCorpus(neg, pos):
    corpus = {"text": [],
              "label": []}
    corpus["text"] = np.concatenate((neg, pos))
    corpus["label"] = np.array(["-1" for i in range(len(neg))]+["1" for i in range(len(pos))], dtype='str')
    return corpus

# %%
#load data
neg = getData("rt-polaritydata/rt-polarity.neg")
poo = getData("rt-polaritydata/rt-polarity.pos")

corpus = getCorpus(neg,pos)
print(corpus['text'].shape)
print(corpus['label'].shape)
# Out:
# (10662,)
# (10662,)

# %%
#preprocessing
corpus['text'] = [entry.lower() for entry in corpus['text']]
corpus['text'] = [word_tokenize(entry) for entry in corpus['text']]


def preprocess_entry(entry):
    tag_map = defaultdict(lambda : wn.NOUN)
    tag_map['J'] = wn.ADJ
    tag_map['V'] = wn.VERB
    tag_map['R'] = wn.ADV
    # Initializing WordNetLemmatizer()
    word_Lemmatized = WordNetLemmatizer()
    # pos_tag function below will provide the 'tag' i.e if the word is Noun(N) or Verb(V) or something else.
    Final_words = [word_Lemmatized.lemmatize(word,tag_map[tag[0]])\
        for word, tag in pos_tag(entry) \
        if word not in stopwords.words('english') and word.isalpha()]
    # The final processed set of words for each iteration will be stored in 'text_final'
    return str(Final_words)

corpus['final_text'] = [preprocess_entry(entry) for entry in corpus['text']]

# %%
for a in zip(corpus['final_text'], corpus['label']):
    print (a)
# Out:
# ("['simplistic', 'silly', 'tedious']", '-1')
# ("['laddish', 'juvenile', 'teenage', 'boy', 'could', 'possibly', 'find', 'funny']", '-1')
# ("['exploitative', 'largely', 'devoid', 'depth', 'sophistication', 'would', 'make', 'watching', 'graphic', 'treatment', 'crime', 'bearable']", '-1')
# ("['garbus', 'discard', 'potential', 'pathological', 'study', 'exhume', 'instead', 'skewed', 'melodrama', 'circumstantial', 'situation']", '-1')
# ("['visually', 'flashy', 'narratively', 'opaque', 'emotionally', 'vapid', 'exercise', 'style', 'mystification']", '-1')
# ("['story', 'also', 'unoriginal', 'come', 'already', 'recycle', 'time', 'care', 'count']", '-1')
# ("['thing', 'give', 'movie', 'point', 'bravado', 'take', 'entirely', 'stale', 'concept', 'push', 'audience', 'meat', 'grinder', 'one', 'time']", '-1')
# ("['much', 'farcical', 'sour']", '-1')
# ("['unfortunately', 'story', 'actor', 'serve', 'hack', 'script']", '-1')
# ("['disquieting', 'relatively', 'allusion', 'serial', 'murder', 'fall', 'attempt', 'humanize', 'subject']", '-1')
# ("['sentimental', 'mess', 'never', 'ring', 'true']", '-1')
# ("['performance', 'often', 'engaging', 'loose', 'collection', 'largely', 'improvised', 'number', 'would', 'probably', 'work', 'well', 'tv', 'documentary']", '-1')
# ("['interesting', 'compelling']", '-1')
# ("['cutting', 'room', 'floor', 'somewhere', 'lie', 'footage', 'might', 'make', 'thing', 'trenchant', 'ironic', 'cultural', 'satire', 'instead', 'frustrating', 'misfire']", '-1')
# ("['ensemble', 'player', 'gain', 'notice', 'guy', 'ritchie', 'lock', 'stock', 'two', 'smoking', 'barrel', 'snatch', 'bod', 'unlikely', 'become', 'household', 'name', 'basis', 'first', 'starring', 'vehicle']", '-1')
# ("['difference', 'movie', 'courage', 'go', 'top', 'movie', 'care', 'stupid']", '-1')
# ("['nothing', 'seem', 'funny', 'analyze', 'even', 'joe', 'viterelli', 'de', 'niro', 'goombah']", '-1')
# ("['master', 'screenwriting', 'come', 'courtesy', 'john', 'pogue', 'yale', 'grad', 'previously', 'give', 'u', 'skull', 'last', 'year', 'rollerball', 'enough', 'say', 'except', 'film', 'overboard']", '-1')
# ("['common', 'sense', 'fly', 'window', 'along', 'hail', 'bullet', 'none', 'ever', 'seem', 'hit', 'sascha']", '-1')
# ("['movie', 'minute', 'decent', 'material']", '-1')
# ("['execution', 'pedestrian', 'positive', 'comment', 'make', 'rob', 'schneider', 'actually', 'turn', 'pretty', 'convincing', 'performance', 'prissy', 'teenage', 'girl']", '-1')
# ("['interesting', 'remake', 'pale', 'imitation']", '-1')
# ("['show', 'studio', 'firmly', 'believe', 'people', 'lose', 'ability', 'think', 'forgive', 'shoddy', 'product', 'long', 'little', 'action']", '-1')
# ("['farce', 'parody', 'comedy', 'premise', 'comparison', 'reality', 'much', 'commentary', 'knowledge', 'film']", '-1')
# ("['exciting', 'exoticism', 'might', 'sound', 'typical', 'pax', 'viewer', 'rest', 'u', 'lull', 'coma']", '-1')
# ("['party', 'scene', 'deliver', 'tawdry', 'kick', 'rest', 'film', 'dudsville']", '-1')
# ("['culture', 'head', 'toilet', 'ferocity', 'frozen', 'burrito', 'tequila', 'bender', 'know', 'see', 'movie']", '-1')
# ("['criticism', 'never', 'rise', 'easy', 'cynical', 'potshot', 'morally', 'bankrupt', 'character']", '-1')
# ("['movie', 'construction', 'feel', 'less', 'product', 'loving', 'well', 'integrated', 'homage', 'like', 'mere', 'excuse', 'wan', 'thinly', 'sketch', 'story', 'kill', 'time', 'go']", '-1')
# ("['stupid', 'infantile', 'redundant', 'sloppy', 'amateurish', 'yep', 'wake', 'reno', 'go', 'back', 'sleep']", '-1')
# ("['somewhere', 'middle', 'film', 'compels', 'demme', 'experiment', 'harvest', 'movie', 'moment', 'gem', 'field', 'roughage', 'dominates']", '-1')
# ("['action', 'clichés', 'pile']", '-1')
# ("['payami', 'try', 'raise', 'serious', 'issue', 'iran', 'electoral', 'process', 'result', 'film', 'subtle', 'party', 'political', 'broadcast']", '-1')
# ("['surprise', 'heavyweight', 'joel', 'silver', 'robert', 'zemeckis', 'agree', 'produce', 'assume', 'director', 'picture', 'cavort', 'lady', 'underwear']", '-1')
# ("['another', 'useless', 'recycling', 'brutal', 'american', 'sport', 'movie']", '-1')
# ("['laugh', 'smile', 'survive']", '-1')
# ("['please', 'someone', 'stop', 'eric', 'schaeffer', 'make', 'another', 'film']", '-1')
# ("['problem', 'film', 'derive', 'screenplay', 'rather', 'mediocre', 'performance', 'actor', 'involve']", '-1')
# ("['mood', 'fun', 'bad', 'movie', 'might', 'want', 'catch', 'freak', 'matinee']", '-1')
# ("['curling', 'may', 'unique', 'sport', 'men', 'broom', 'distinctly', 'ordinary']", '-1')
# ("['though', 'opera', 'take', 'place', 'mostly', 'indoors', 'jacquot', 'seem', 'unsure', 'evoke', 'sort', 'naturalism', 'set']", '-1')
# ("['get', 'around', 'fact', 'revenge', 'nerd', 'revisit']", '-1')
# ("['effort', 'sincere', 'result', 'honest', 'film', 'bleak', 'hardly', 'watchable']", '-1')
# ("['analyze', 'regurgitate', 'water', 'many', 'previous', 'film', 'success', 'new', 'swing', 'throw']", '-1')
# ("['flashbulb', 'edit', 'cover', 'absence', 'narrative', 'continuity', 'undisputed', 'nearly', 'incoherent', 'excuse', 'get', 'closing', 'bout', 'time', 'impossible', 'care', 'win']", '-1')
# ("['stink', 'start', 'finish', 'like', 'wet', 'burlap', 'sack', 'gloom']", '-1')
# ("['civilize', 'mind', 'movie', 'like', 'ballistic', 'eck', 'vs', 'sever', 'ordeal', 'amusement']", '-1')
# ("['equlibrium', 'could', 'pass', 'book', 'report', 'totalitarian', 'theme', 'farenheit']", '-1')
# ("['lack', 'naturalness', 'make', 'everything', 'seem', 'poetic', 'force', 'pity', 'nelson', 'achievement', 'match', 'ambition']", '-1')
# ("['everything']", '-1')
# ("['seagal', 'appear', 'orange', 'prison', 'jumpsuit', 'want', 'stand', 'theater', 'shout']", '-1')
# ("['easy', 'watch', 'except', 'annoy', 'demeanour', 'lead', 'character']", '-1')
# ("['imagine', 'cleanflicks', 'version', 'story', 'ali', 'macgraw', 'profanity', 'replace', 'platitude']", '-1')
# ("['pc', 'stability', 'notwithstanding', 'film', 'suffers', 'simplistic', 'narrative', 'pat', 'conclusion']", '-1')
# ("['forget', 'misleading', 'title', 'unexplained', 'baboon', 'cameo']", '-1')
# ("['odd', 'haphazard', 'inconsequential', 'romantic', 'comedy']", '-1')
# ("['though', 'fan', 'assuredly', 'funny', 'bone', 'tickle', 'others', 'find', 'dollar', 'best', 'spend', 'elsewhere']", '-1')
# ("['pascale', 'bailly', 'provide', 'amélie', 'audrey', 'tautou', 'another', 'fabuleux', 'destin', 'e', 'banal', 'spiritual', 'quest']", '-1')
# ("['static', 'sugary', 'little', 'special', 'interfaith', 'understanding', 'stretch', 'minute']", '-1')
# ("['watch', 'chemistry', 'freeman', 'judd', 'however', 'almost', 'make', 'movie', 'worth', 'see', 'almost']", '-1')
# ("['pretentious', 'ultimately', 'empty', 'examination', 'sick', 'evil', 'woman']", '-1')
# ("['country', 'bear', 'scene', 'upset', 'frighten', 'young', 'viewer', 'unfortunately', 'almost', 'nothing', 'flat', 'effort', 'amuse', 'entertain', 'either']", '-1')
# ("['cumulative', 'effect', 'watch', 'trifle', 'rather', 'like', 'trap', 'weird', 'relative', 'trot', 'video', 'take', 'family', 'vacation', 'stonehenge', 'long', 'desperate', 'evening', 'end']", '-1')
# ("['character', 'never', 'sketch', 'leave', 'true', 'emotional', 'connection', 'identification', 'frustratingly', 'reach']", '-1')
# ("['mattei', 'underdeveloped', 'effort', 'nothing', 'convenient', 'conveyor', 'belt', 'brood', 'personality', 'parade', 'come', 'back', 'stock', 'character', 'camp', 'drowsy', 'drama', 'infatuate', 'pretentious']", '-1')
# ("['final', 'surprising', 'shot', 'fence', 'find', 'authority', 'look']", '-1')
# ("['sharp', 'original', 'despite', 'visual', 'virtue', 'ii', 'cut']", '-1')
# ("['play', 'like', 'badly', 'edit', 'trailer', 'director', 'ca', 'seem', 'get', 'coherent', 'rhythm', 'go', 'fact', 'even', 'seem', 'like', 'try']", '-1')
# ("['maybe', 'leblanc', 'thought', 'hey', 'movie', 'monkey', 'bad']", '-1')
# ("['expect', 'get', 'assume', 'bar', 'expectation', 'raise', 'height']", '-1')
# ("['barry', 'sonnenfeld', 'owes', 'frank', 'pug', 'big', 'time']", '-1')
# ("['big', 'problem', 'roger', 'avary', 'uproar', 'mpaa', 'even', 'director', 'cut', 'glory', 'make', 'film', 'barely', 'shocking', 'barely', 'interesting', 'barely', 'anything']", '-1')
# ("['riddled', 'unanswered', 'question', 'require', 'gargantuan', 'leap', 'faith', 'watch', 'plod', 'along']", '-1')
# ("['approach', 'usher', 'say', 'sit', 'ask', 'raise']", '-1')
# ("['earnest']", '-1')
# ("['sinise', 'character', 'brain', 'ordeal', 'would', 'five', 'minute', 'instead', 'plot', 'go', 'way', 'introduce', 'obstacle', 'stumble']", '-1')
# ("['slow', 'young', 'crowd', 'shallow', 'old', 'one']", '-1')
# ("['reason', 'studio', 'offer', 'advance', 'screening', 'adventure', 'pluto', 'nash', 'big', 'time', 'stinker']", '-1')
# ("['punch', 'line', 'without', 'premise', 'joke', 'build', 'entirely', 'musty', 'memory', 'character']", '-1')
# ("['take', 'one', 'character', 'like', 'another', 'believe', 'put', 'battle', 'will', 'impossible', 'care', 'funny']", '-1')
# ("['thing', 'movie', 'try', 'get', 'audience', 'buy', 'wo', 'fly', 'intelligent', 'viewer']", '-1')
# ("['even', 'entice', 'prospect', 'lot', 'nubile', 'young', 'actor', 'film', 'campus', 'depravity', 'fade', 'amid', 'deliberate', 'tiresome', 'ugliness', 'would', 'render', 'tedious', 'avary', 'failure', 'construct', 'story', 'even', 'trace', 'dramatic', 'interest']", '-1')
# ("['sit', 'last', 'reel', 'spoiler', 'alert', 'significantly', 'less', 'charm', 'listen', 'taste', 'exaggeration', 'recount', 'halloween', 'trip', 'haunt', 'house']", '-1')
# ("['confuse', 'message', 'ultimate', 'desire', 'please', 'contort', 'idea', 'expectation', 'last', 'thing', 'three', 'actress', 'character', 'deserve']", '-1')
# ("['deadly', 'dull', 'pointless', 'meditation', 'loser', 'hotel']", '-1')
# ("['new', 'rollerball', 'sense', 'sensibility', 'overrun', 'characterize', 'robotic', 'sentiment']", '-1')
# ("['one', 'assume', 'jury', 'bestow', 'star', 'hoffman', 'brother', 'gordy', 'waldo', 'salt', 'screenwriting', 'award', 'sundance', 'festival', 'honor', 'attempt', 'something', 'different', 'actually', 'pull']", '-1')
# ("['movie', 'prescribe', 'recommend', 'visually', 'bland', 'dentist', 'waiting', 'room', 'complete', 'soothe', 'muzak', 'cushion', 'predictable', 'narrative', 'rhythm']", '-1')
# ("['sex', 'ironically', 'little', 'story', 'become', 'something', 'lame', 'try', 'evade', 'responsibility', 'never', 'ever', 'leave', 'large', 'dog', 'alone', 'toddler', 'never', 'mind', 'boob', 'fantasti']", '-1')
# ("['script', 'cover', 'huge', 'heavy', 'topic', 'bland', 'surfacey', 'way', 'offer', 'insight', 'instance', 'good', 'thing', 'happen', 'bad', 'people']", '-1')
# ("['portrait', 'alienation', 'perfect', 'certainly', 'succeed', 'alienate', 'viewer']", '-1')
# ("['code', 'talker', 'deserve', 'good', 'hollow', 'tribute']", '-1')
# ("['skip', 'film', 'buy', 'philip', 'glass', 'soundtrack', 'cd']", '-1')
# ("['feel', 'like', 'cold', 'old', 'man', 'go', 'motion']", '-1')
# ("['dignify', 'ceo', 'meet', 'rustic', 'retreat', 'pee', 'tree', 'bear', 'laughter']", '-1')
# ("['dull', 'mechanical', 'kinda', 'like', 'goofy', 'museum', 'exhibit']", '-1')
# ("['point', 'view', 'contemporary', 'interpretation', 'joan', 'prefeminist', 'plight', 'leave', 'think', 'reason', 'make', 'movie', 'present', 'standard', 'allow', 'plenty', 'nudity']", '-1')
# ("['beware', 'quirky', 'turn', 'dime', 'oddly', 'humorous', 'tediously', 'sentimental']", '-1')
# ("['moment', 'almost', 'many', 'subplots']", '-1')
# ("['gag', 'script', 'mixed', 'bag']", '-1')
# ("['completely', 'awful', 'iranian', 'drama', 'much', 'fun', 'grouchy', 'ayatollah', 'cold', 'mosque']", '-1')
# ("['narratively', 'trouble', 'every', 'day', 'plod', 'mess']", '-1')
# ("['point', 'extract', 'bare', 'bone', 'byatt', 'plot', 'purpose', 'bland', 'hollywood', 'romance']", '-1')
# ("['director', 'john', 'musker', 'ron', 'clements', 'team', 'behind', 'little', 'mermaid', 'produce', 'sparkling', 'retina', 'candy', 'able', 'muster', 'lot', 'emotional', 'resonance', 'cold', 'vacuum', 'space']", '-1')
# ("['adam', 'sandler', 'heart', 'may', 'right', 'place', 'need', 'pull', 'head', 'butt']", '-1')
# ("['doubting', 'highly', 'ambitious', 'personal', 'project', 'egoyan', 'also', 'one', 'next', 'best', 'work', 'feel', 'clumsy', 'convolute']", '-1')
# ("['despite', 'engage', 'offbeat', 'touch', 'knockaround', 'guy', 'rarely', 'seem', 'interested', 'kick', 'around', 'raison', 'cast']", '-1')
# ("['pretty', 'tame', 'offensive', 'thing', 'movie', 'hollywood', 'expect', 'people', 'pay', 'see']", '-1')
# ("['movie', 'mess', 'start', 'finish']", '-1')
# ("['trouble', 'make', 'queen', 'thoroughly', 'modern', 'maiden', 'also', 'make', 'appear', 'foolish', 'shallow', 'rather', 'likely', 'victim', 'mental', 'illness']", '-1')
# ("['say', 'ice', 'age', 'fairly', 'pretty', 'picture', 'enough', 'substance', 'story', 'actually', 'give', 'life']", '-1')
# ("['telling', 'story', 'largely', 'untold', 'bui', 'chooses', 'produce', 'something', 'ultimately', 'suspiciously', 'familiar']", '-1')
# ("['plot', 'nothing', 'boilerplate', 'clichés', 'start', 'finish', 'script', 'assume', 'would', 'subtlety', 'lose', 'target', 'audience', 'also', 'stupid', 'realize', 'already', 'see', 'exact', 'movie', 'hundred', 'time']", '-1')
# ("['terminally', 'brain', 'dead', 'production']", '-1')
# ("['episode', 'work']", '-1')
# ("['beautifully', 'film', 'well', 'act', 'admittedly', 'problematic', 'narrative', 'specific']", '-1')
# ("['j', 'lo', 'earn', 'share', 'holiday', 'box', 'office', 'pie', 'although', 'movie', 'make', 'one', 'thing', 'perfectly', 'clear', 'pretty', 'woman', 'working', 'girl']", '-1')
# ("['rymer', 'trust', 'laugh', 'conjure', 'proper', 'respect', 'follower', 'whole', 'genre', 'deserve', 'vampire', 'pic', 'shrieky', 'special', 'effect']", '-1')
# ("['film', 'soprano', 'gag', 'incredibly', 'date', 'unfunny', 'also', 'demonstrate', 'desperate', 'maker', 'sequel']", '-1')
# ("['wow', 'disappoint', 'movie', 'long', 'time']", '-1')
# ("['hook', 'overlong', 'credit', 'adam', 'watstein', 'finish']", '-1')
# ("['drag', 'nettelbeck', 'see', 'work', 'woman', 'least', 'work', 'woman', 'show', 'little', 'understanding']", '-1')
# ("['watch', 'harris', 'ham', 'physically', 'emotionally', 'disintegrate', 'course', 'movie', 'certain', 'poignancy', 'light', 'recent', 'death', 'boyd', 'film', 'offer', 'little', 'else', 'consequence']", '-1')
# ("['also', 'curious', 'note', 'film', 'like', 'similarly', 'antitrust', 'easily', 'bad', 'fraction', 'budget']", '-1')
# ("['de', 'una', 'cinta', 'en', 'que', 'importa', 'el', 'talento', 'de', 'su', 'reparto', 'lo', 'interesante', 'que', 'pudo', 'haber', 'resultado', 'su', 'premisa', 'pues', 'el', 'resultado', 'e', 'francamente', 'aburrido', 'por', 'momentos', 'deplorable']", '-1')
# ("['probably', 'one', 'movie', 'barely', 'register', 'blip', 'radar', 'screen']", '-1')
# ("['problem', 'derivative', 'plenty', 'funny', 'movie', 'recycle', 'old', 'trope', 'problem', 'van', 'wilder', 'little', 'actually', 'funny', 'material']", '-1')
# ("['nothing', 'interesting', 'unfaithful', 'whatsoever']", '-1')
# ("['none', 'half', 'move', 'filmmaker', 'seem', 'think']", '-1')
# ("['processed', 'comedy', 'chop', 'suey']", '-1')
# ("['spent', 'screen', 'series', 'go', 'star', 'trek', 'nemesis', 'even', 'suggestive', 'class', 'reunion', 'mixer', 'eight', 'survive', 'member', 'show', 'nothing', 'drink']", '-1')
# ("['fails', 'dystopian', 'movie', 'retooling', 'fahrenheit', 'even', 'matrix']", '-1')
# ("['full', 'kind', 'obnoxious', 'chitchat', 'neurotic', 'engage']", '-1')
# ("['erotic', 'thriller', 'neither', 'erotic', 'thrilling', 'either']", '-1')
# ("['movie', 'like', 'bartleby', 'something', 'stiff', 'office', 'comedy', 'seem', 'twice', 'long', 'minute']", '-1')
# ("['parade', 'almost', 'perpetually', 'wasted', 'character', 'margarita', 'feel', 'like', 'hazy', 'high', 'take', 'long', 'shake']", '-1')
# ("['value', 'time', 'money', 'find', 'escape', 'clause', 'avoid', 'see', 'trite', 'predictable', 'rehash']", '-1')
# ("['director', 'capable', 'cast', 'appear', 'catch', 'heady', 'whirl', 'new', 'good', 'intention', 'spell', 'cast', 'least', 'bit', 'mesmerize']", '-1')
# ("['everything', 'peg', 'groove', 'new', 'york', 'date', 'comedy', 'simplify']", '-1')
# ("['dramatic', 'comedy', 'pleasantly', 'dishonest', 'pat', 'hollywood', 'fluff']", '-1')
# ("['title', 'sequence', 'funny', 'minute', 'date', 'spy', 'comedy', 'franchise', 'mike', 'myers', 'show', 'ruin', 'everything']", '-1')
# ("['come', 'silly', 'would', 'surprise', 'ba', 'murdock', 'rest', 'see', 'give', 'chase', 'black', 'red', 'van']", '-1')
# ("['lovebird', 'immature', 'unappealing', 'care']", '-1')
# ("['genial', 'conceit', 'one', 'rare', 'picture', 'root', 'throughout', 'dearly', 'hop', 'rich', 'promise', 'script', 'realize', 'screen', 'never', 'fully']", '-1')
# ("['even', 'summertime', 'restless', 'young', 'audience', 'deserve', 'dignity', 'action', 'hero', 'motivate', 'something', 'franchise', 'possibility']", '-1')
# ("['blanket', 'statement', 'rumination', 'vanity', 'worry', 'rich', 'sudden', 'wisdom', 'film', 'become', 'sermon', 'running', 'time']", '-1')
# ("['one', 'lousy', 'movie']", '-1')
# ("['gamely', 'movie', 'try', 'make', 'sense', 'title', 'character', 'remain', 'huge', 'gap', 'film', 'creepy', 'dahmer', 'jeremy', 'renner', 'fiendish', 'act', 'amount', 'earnest', 'textbook', 'psychologizing', 'bridge']", '-1')
# ("['plodding', 'peevish', 'gimmicky']", '-1')
# ("['four', 'feather', 'definitely', 'horse', 'feather', 'go', 'know', 'might', 'fun', 'cinematic', 'sandbox']", '-1')
# ("['oozes', 'condescension', 'every', 'pore']", '-1')
# ("['solaris', 'shapeless', 'inconsequential', 'move', 'rely', 'viewer', 'work']", '-1')
# ("['direction', 'george', 'hickenlooper', 'snap', 'wiseacre', 'crackle', 'cynicism']", '-1')
# ("['hypnotically', 'dull']", '-1')
# ("['though', 'saga', 'would', 'terrific', 'read', 'dicey', 'screen', 'material', 'genius', 'touch']", '-1')
# ("['plenty', 'laugh', 'much', 'else', 'especially', 'moral', 'sense']", '-1')
# ("['awful', 'lot', 'like', 'one', 'spear', 'music', 'video', 'content', 'except', 'go', 'least', 'minute', 'bad', 'pay', 'want', 'see']", '-1')
# ("['confusion', 'one', 'least', 'favourite', 'emotion', 'especially', 'put', 'minute']", '-1')
# ("['h', 'ad', 'suffer', 'bleed', 'hard', 'ground', 'ia', 'drang', 'want', 'something', 'bit', 'complex', 'soldier', 'remember']", '-1')
# ("['occasionally', 'loud', 'offensive', 'often', 'simply', 'lull', 'gentle', 'waking', 'coma']", '-1')
# ("['may', 'play', 'well', 'double', 'feature', 'mainstream', 'foreign', 'mush', 'like', 'big', 'fat', 'greek', 'wedding']", '-1')
# ("['time', 'reach', 'finale', 'likely', 'wonder', 'watch', 'strutting', 'posturing']", '-1')
# ("['journalistically', 'dubious', 'inept', 'often', 'lethally', 'dull']", '-1')
# ("['put', 'primitive', 'murderer', 'inside', 'space', 'station', 'unleash', 'pandora', 'box', 'special', 'effect', 'run', 'gamut', 'cheesy', 'cheesier', 'cheesiest']", '-1')
# ("['best', 'black', 'hawk', 'heart', 'bad', 'ford']", '-1')
# ("['exactly', 'expect', 'guy', 'name', 'kaos']", '-1')
# ("['calculate', 'swill']", '-1')
# ("['movie', 'deserve', 'energy', 'take', 'describe', 'bad']", '-1')
# ("['without', 'ballast', 'tank', 'sink', 'harrison', 'ford', 'low']", '-1')
# ("['director', 'oliver', 'parker', 'labor', 'hard', 'whip', 'life', 'importance', 'earnest', 'probably', 'pull', 'muscle', 'two']", '-1')
# ("['might', 'shock', 'discover', 'seinfeld', 'real', 'life', 'boring']", '-1')
# ("['nearly', 'fresh', 'enjoyable', 'predecessor', 'enough', 'high', 'point', 'keep', 'complete', 'waste', 'time']", '-1')
# ("['walsh', 'ca', 'quite', 'negotiate', 'many', 'inconsistency', 'janice', 'behavior', 'compensate', 'sheer', 'force', 'charm']", '-1')
# ("['film', 'series', 'look', 'feel', 'tire']", '-1')
# ("['leer', 'offer', 'next', 'little', 'insight', 'intriguing', 'subject']", '-1')
# ("['find', 'grow', 'frustrated', 'detach', 'vincent', 'become', 'abhorrent']", '-1')
# ("['one', 'odd', 'inexplicable', 'sequel', 'movie', 'history']", '-1')
# ("['nothing', 'gain', 'watch', 'scary', 'hat', 'character', 'find', 'way', 'entertain', 'inspire', 'viewer']", '-1')
# ("['fear', 'permeate', 'whole', 'stortelling', 'todd', 'solondz', 'oftentimes', 'funny', 'yet', 'ultimately', 'cowardly', 'autocritique']", '-1')
# ("['skirmish', 'power', 'wag', 'among', 'victim', 'predator', 'settle', 'undistinguished', 'rhythm', 'artificial', 'suspense']", '-1')
# ("['thoroughly', 'awful']", '-1')
# ("['ice', 'age', 'tread', 'predictably', 'along', 'familiar', 'territory', 'make', 'passable', 'family', 'film', 'wo', 'win', 'many', 'fan', 'age']", '-1')
# ("['though', 'film', 'one', 'could', 'rent', 'original', 'get', 'love', 'story', 'parable']", '-1')
# ("['silly', 'sophomoric', 'ensnare', 'target', 'audience']", '-1')
# ("['video', 'work', 'grainy', 'rough', 'dependent', 'rather', 'carefully', 'lit', 'set', 'exhaust', 'watch']", '-1')
# ("['truly', 'terrible']", '-1')
# ("['cleverly', 'craft', 'ultimately', 'hollow', 'mockumentary']", '-1')
# ("['get', 'bogged', 'topical', 'humour', 'get', 'truly', 'good', 'stuff']", '-1')
# ("['achingly', 'enthral', 'premise', 'film', 'hinder', 'uneven', 'dialogue', 'plot', 'lapse']", '-1')
# ("['tommy', 'job', 'clean', 'peep', 'booth', 'surround', 'view', 'one', 'feel', 'like', 'mop']", '-1')
# ("['rifkin', 'doubt', 'fancy', 'something', 'hubert', 'selby', 'jr', 'ounce', 'honest', 'poetry', 'entire', 'script', 'simply', 'crude', 'unrelentingly', 'exploitative']", '-1')
# ("['fluffy', 'disposible']", '-1')
# ("['bad', 'movie', 'lucky', 'viewer', 'seat', 'next', 'one', 'ignorant', 'pinhead', 'talk', 'throughout', 'show']", '-1')
# ("['go', 'theater', 'expect', 'scary', 'chiller', 'might', 'soon', 'look', 'sign', 'exit', 'sign']", '-1')
# ("['hold', 'limited', 'appeal', 'like', 'explosion', 'sadism', 'see', 'people', 'beat', 'pulp']", '-1')
# ("['dialogue', 'choppy', 'monosyllabic', 'despite', 'fact', 'dub']", '-1')
# ("['version', 'mama', 'family']", '-1')
# ("['end', 'get', 'vertical', 'limit', 'surf', 'movie', 'memorable', 'stunt', 'lot', 'downtime']", '-1')
# ("['steal', 'harvard', 'care', 'cleverness', 'wit', 'kind', 'intelligent', 'humor']", '-1')
# ("['bigelow', 'handle', 'nuclear', 'crisis', 'sequence', 'evenly', 'milk', 'drama', 'build', 'suspense', 'drag', 'many', 'scene', 'toward', 'end', 'move', 'quickly']", '-1')
# ("['undeniable', 'enjoyment', 'film', 'cram', 'movie', 'reference', 'fun', 'wear', 'thin', 'nothing', 'else', 'happen']", '-1')
# ("['imagine', 'kevin', 'smith', 'blasphemous', 'bad', 'boy', 'suburban', 'jersey', 'strip', 'budget', 'sense', 'humor', 'result', 'might', 'look', 'like', 'vulgar']", '-1')
# ("['suffers', 'lack', 'clarity', 'audacity', 'subject', 'monstrous', 'pathetic', 'dahmer', 'demand']", '-1')
# ("['sour', 'santa', 'clause', 'santa', 'bump', 'century', 'reality', 'hard', 'icky']", '-1')
# ("['highlight', 'reel', 'minute', 'long']", '-1')
# ("['film', 'favor', 'scientific', 'spectacular', 'visually', 'speak']", '-1')
# ("['incomprehensible', 'mess', 'feel', 'less', 'like', 'bad', 'cinema', 'like', 'stick', 'dark', 'pit', 'nightmare', 'bad', 'cinema']", '-1')
# ("['exception', 'mccoist', 'player', 'clue', 'park', 'acting', 'much', 'good']", '-1')
# ("['whole', 'affair', 'predictable']", '-1')
# ("['secret', 'sisterhood', 'hefty', 'help', 'green', 'tomato']", '-1')
# ("['cloying', 'story', 'hell']", '-1')
# ("['suffocate', 'horror', 'show', 'hinge', 'subgenre', 'enabling', 'victim', 'ebullient', 'affection', 'meat', 'freezer']", '-1')
# ("['star', 'trek', 'kind', 'terrific', 'copy', 'copy', 'copy']", '-1')
# ("['n', 'matter', 'much', 'good', 'actor', 'generate', 'showtime', 'eventually', 'fold', 'thinness']", '-1')
# ("['every', 'potential', 'twist', 'telegraph', 'well', 'advance', 'every', 'performance', 'respectably', 'mute', 'movie', 'seem', 'make', 'influence', 'rohypnol']", '-1')
# ("['put', 'air', 'hal', 'hartley', 'wannabe', 'film', 'without', 'vital', 'comic', 'ingredient', 'hilarious']", '-1')
# ("['ver', 'wiel', 'desperate', 'attempt', 'wit', 'lose', 'leave', 'character', 'critical', 'jim', 'pointless']", '-1')
# ("['despite', 'performance', 'sustained', 'intelligence', 'stanford', 'another', 'subtle', 'humour', 'bebe', 'neuwirth', 'old', 'woman', 'seduce', 'oscar', 'film', 'founder', 'lack', 'empathy', 'social', 'milieu', 'rich', 'new', 'york', 'intelligentsia']", '-1')
# ("['although', 'disney', 'follow', 'standard', 'formula', 'animated', 'adventure', 'feel', 'forced', 'usual']", '-1')
# ("['gaghan', 'throw', 'every', 'suspenseful', 'cliché', 'book', 'nonsensical', 'story']", '-1')
# ("['sham', 'construct', 'base', 'theory', 'hypothesis']", '-1')
# ("['p', 'artnering', 'murphy', 'robert', 'de', 'niro', 'comedy', 'showtime', 'would', 'seem', 'surefire', 'casting', 'catch', 'stick', 'script', 'prevent', 'fire', 'cylinder']", '-1')
# ("['laugh', 'quite', 'hour', 'half', 'come', 'feel', 'strangely', 'unsatisfied', 'feel', 'like', 'eat', 'reeses', 'without', 'peanut', 'butter']", '-1')
# ("['gooding', 'offer', 'desperately', 'ingratiating', 'performance']", '-1')
# ("['parker', 'commend', 'take', 'fresh', 'approach', 'familiar', 'material', 'determination', 'remain', 'true', 'original', 'text', 'lead', 'adopt', 'somewhat', 'mannered', 'tone', 'ultimately', 'dull', 'human', 'tragedy', 'story', 'core']", '-1')
# ("['director', 'inject', 'proceeding', 'every', 'turn', 'result', 'far', 'alienating', 'involve']", '-1')
# ("['bogdanich', 'unashamedly', 'make', 'little', 'attempt', 'give', 'voice', 'side']", '-1')
# ("['lack', 'thesis', 'make', 'maryam', 'end', 'play', 'intellectual', 'emotional', 'impact', 'special']", '-1')
# ("['bad', 'film', 'year']", '-1')
# ("['yarn']", '-1')
# ("['without', 'shakespeare', 'eloquent', 'language', 'update', 'dreary', 'sluggish']", '-1')
# ("['h', 'g', 'well', 'time', 'machine', 'could', 'take', 'look', 'kin', 'reworked', 'version', 'would', 'say', 'look', 'good', 'sonny', 'miss', 'point']", '-1')
# ("['tuxedo', 'minute', 'screen', 'time', 'one', 'true', 'moment']", '-1')
# ("['bisset', 'delivers', 'game', 'performance', 'unable', 'save', 'movie']", '-1')
# ("['watch', 'austin', 'power', 'goldmember', 'like', 'binge', 'cotton', 'candy', 'sweet', 'fluffy', 'time', 'may', 'leave', 'feel', 'little', 'sticky', 'unsatisfied']", '-1')
# ("['big', 'studio', 'picture', 'since', 'mile', 'graceland']", '-1')
# ("['film', 'depress', 'life']", '-1')
# ("['sure', 'filmmaker', 'find', 'remarkable', 'novel', 'concept', 'anybody', 'ever', 'see', 'independent', 'film', 'report', 'instead', 'cheap', 'cliché']", '-1')
# ("['acting', 'fine', 'script', 'interesting', 'recording', 'conversation', 'checkout', 'line']", '-1')
# ("['weighty', 'theme', 'grave', 'youngster', 'story', 'steep', 'fairy', 'tale', 'childish', 'thing', 'appeal', 'much', 'teenager']", '-1')
# ("['plot', 'plummet', 'comedy', 'graveyard', 'janice', 'come', 'race', 'rescue', 'final', 'reel']", '-1')
# ("['sometimes', 'good', 'reason', 'certain', 'movie', 'seal', 'jar', 'leave', 'remote', 'shelf', 'indefinitely']", '-1')
# ("['minute', 'movie', 'short', 'feel', 'much', 'longer']", '-1')
# ("['advice', 'kev', 'start', 'read', 'script', 'sign', 'dotted', 'line']", '-1')
# ("['alternately', 'raucous', 'sappy', 'ethnic', 'sitcom', 'wise', 'send', 'regret']", '-1')
# ("['tale', 'hideously', 'clumsily', 'tell', 'feel', 'accidental']", '-1')
# ("['unfortunately', 'also', 'good', 'especially', 'compare', 'television', 'series', 'inspire', 'movie']", '-1')
# ("['wrap', 'classic', 'struggle', 'recycled', 'paper', 'shiny', 'new', 'bow', 'audience', 'tell', 'new', 'least', 'look', 'pretty']", '-1')
# ("['glaze', 'tawdry', 'scum']", '-1')
# ("['kind', 'movie', 'want', 'bang', 'head', 'seat', 'front', 'cluelessness', 'idiocy', 'utterly', 'misplace', 'earnestness']", '-1')
# ("['wind', 'move', 'many', 'direction', 'search', 'vainly', 'think', 'something', 'fresh', 'say']", '-1')
# ("['road', 'perdition', 'love', 'strangeness', 'excellence']", '-1')
# ("['big', 'fat', 'pain']", '-1')
# ("['mimetic', 'approximation', 'good', 'film', 'like', 'contempt']", '-1')
# ("['unintelligible', 'poorly', 'act', 'bad', 'harvard', 'man', 'ludicrous', 'enough', 'could', 'become', 'cult', 'classic']", '-1')
# ("['watch', 'powerpuff', 'girl', 'movie', 'mind', 'keep', 'return', 'one', 'anecdote', 'comparison', 'cartoon', 'japan', 'give', 'people', 'seizure']", '-1')
# ("['aan', 'opportunity', 'waste']", '-1')
# ("['inelegant', 'combination', 'two', 'unrelated', 'short', 'fall', 'far', 'short', 'director', 'previous', 'work', 'term', 'thematic', 'content', 'narrative', 'strength']", '-1')
# ("['build', 'fantasy', 'around', 'vain', 'say', 'least', 'mention', 'inappropriate', 'wildly', 'undeserved']", '-1')
# ("['cheesy', 'monster', 'side', 'horror', 'spoof', 'likely', 'induce', 'sleep', 'fright']", '-1')
# ("['mild', 'meander', 'teen', 'flick']", '-1')
# ("['though', 'atmosphere', 'intrigue', 'drama', 'finally', 'predictable', 'leave', 'much', 'impression']", '-1')
# ("['though', 'rude', 'crude', 'film', 'deliver', 'laugh', 'dig', 'modern', 'society', 'thing', 'see']", '-1')
# ("['although', 'try', 'much', 'really', 'another', 'major', 'league']", '-1')
# ("['astonishing', 'word', 'neither', 'incompetent', 'incoherent', 'plain', 'crap', 'indeed', 'none', 'word', 'really', 'get', 'special', 'type', 'badness', 'deuce', 'wild']", '-1')
# ("['one', 'thing', 'sure', 'movie', 'tell', 'whole', 'lot', 'lily']", '-1')
# ("['tone', 'variable', 'cinematography', 'schaeffer', 'film', 'never', 'settle', 'enchantment', 'material', 'need', 'character', 'quirk', 'foible', 'never', 'jell', 'charm']", '-1')
# ("['good', 'understand', 'connect', 'would', 'require', 'another', 'viewing', 'wo', 'sit', 'one', 'commentary', 'enough']", '-1')
# ("['cuba', 'gooding', 'jr', 'valiantly', 'mug', 'way', 'snow', 'dog', 'even', 'boisterous', 'energy', 'fails', 'spark', 'leaden', 'comedy']", '-1')
# ("['diane', 'lane', 'sophisticated', 'performance', 'ca', 'rescue', 'adrian', 'lyne', 'unfaithful', 'sleazy', 'moralizing']", '-1')
# ("['clear', 'try', 'say', 'even', 'doubt', 'would', 'interesting']", '-1')
# ("['storytelling', 'feel', 'slight']", '-1')
# ("['swimfan', 'fall', 'victim', 'sloppy', 'plotting', 'insultingly', 'unbelievable', 'final', 'act', 'villainess', 'crazy', 'interesting']", '-1')
# ("['remake', 'lina', 'wertmuller', 'might', 'big', 'disaster', 'since', 'john', 'bo', 'derek', 'make', 'ridiculous', 'bolero']", '-1')
# ("['silly', 'loud', 'goofy']", '-1')
# ("['spend', 'stuff', 'get', 'buck', 'greasy', 'little', 'vidgame', 'pit', 'theater', 'lobby']", '-1')
# ("['french', 'director', 'turn', 'nearly', 'hour', 'unfocused', 'excruciatingly', 'tedious', 'cinema', 'half', 'hour', 'start', 'make', 'water', 'torture', 'seem', 'appeal']", '-1')
# ("['basic', 'premise', 'intrigue', 'quickly', 'become', 'distasteful', 'downright', 'creepy']", '-1')
# ("['pool', 'drown', 'boredom']", '-1')
# ("['like', 'salute', 'disney', 'cheesy', 'commercialism']", '-1')
# ("['hard', 'imagine', 'recent', 'film', 'independent', 'otherwise', 'make', 'much', 'mess', 'one']", '-1')
# ("['computer', 'animation', 'handsome', 'various', 'amuse', 'sidekick', 'add', 'levity', 'otherwise', 'bleak', 'tale', 'overall', 'film', 'never', 'rise', 'mediocrity']", '-1')
# ("['excellent', 'film', 'unfortunately', 'run']", '-1')
# ("['saccharine', 'movie', 'go', 'likely', 'cause', 'massive', 'cardiac', 'arrest', 'take', 'large', 'dos']", '-1')
# ("['die', 'another', 'day', 'intermittently', 'entertain', 'hard', 'sucker', 'charm', 'perhaps', 'impossible', 'feel', 'nostalgia', 'movie', 'grow']", '-1')
# ("['often', 'case', 'ambitious', 'eager', 'filmmaker', 'mr', 'murray', 'prolific', 'director', 'music', 'video', 'stuff', 'debut', 'plot', 'comfortably', 'hold']", '-1')
# ("['mystery', 'enigma', 'rich', 'historical', 'subject', 'combine', 'much', 'talent', 'could', 'yield', 'flat', 'plodding', 'picture']", '-1')
# ("['throw', 'quirky', 'character', 'odd', 'situation', 'dialogue', 'u', 'say', 'look', 'interesting', 'movie', 'film', 'ultimately', 'quite', 'unengaging']", '-1')
# ("['inherent', 'limitation', 'use', 'video', 'game', 'source', 'material', 'movie', 'make', 'clear', 'schlocky', 'hybrid']", '-1')
# ("['bad', 'company', 'bad', 'movie', 'plain', 'bad']", '-1')
# ("['dull', 'see', 'eddie', 'murphy', 'shtick', 'death', 'plot', 'equally', 'hackneyed']", '-1')
# ("['avary', 'film', 'never', 'quite', 'emerge', 'shadow', 'elli', 'book']", '-1')
# ("['poorly', 'script', 'preachy', 'fable', 'forget', 'unfold', 'coherent', 'believable', 'story', 'zeal', 'spread', 'propaganda']", '-1')
# ("['interest', 'witness', 'conflict', 'palestinian', 'side', 'longley', 'film', 'lack', 'balance', 'fail', 'put', 'struggle', 'meaningful', 'historical', 'context']", '-1')
# ("['woo', 'much', 'right', 'make', 'huge', 'action', 'sequence', 'director', 'long', 'filmmaker', 'copy', 'saving', 'private', 'ryan', 'battle', 'scene', 'realize', 'steven', 'spielberg', 'get', 'right', 'first', 'time']", '-1')
# ("['sincere', 'fault', 'unfortunately', 'compel', 'much', 'fun']", '-1')
# ("['jones', 'despite', 'definitely', 'distinctive', 'screen', 'presence', 'able', 'muster', 'movie', 'title', 'notwithstanding', 'lot', 'nasty', 'want', 'fully', 'capitalize', 'lead', 'specific', 'gift']", '-1')
# ("['seem', 'similar', 'disney', 'classic', 'make', 'one', 'long', 'geriatric', 'peter']", '-1')
# ("['may', 'ask', 'buy', 'movie', 'milk', 'tv', 'cow', 'free', 'good', 'answer', 'one']", '-1')
# ("['swedish', 'film', 'offer', 'even', 'hint', 'joy', 'prefer', 'focus', 'humiliation', 'martin', 'defecate', 'bed', 'urinates', 'plant', 'birthday', 'party']", '-1')
# ("['muddled', 'limp', 'biscuit', 'movie', 'vampire', 'soap', 'opera', 'make', 'much', 'sense', 'even', 'term']", '-1')
# ("['plot', 'maddeningly', 'insistent', 'repetitive', 'piano', 'score', 'make', 'want', 'scream']", '-1')
# ("['movie', 'insecure', 'capacity', 'excite', 'churn', 'one', 'two', 'flagrantly', 'fake', 'thunderstorm', 'underscore', 'action']", '-1')
# ("['amuse', 'three', 'minute']", '-1')
# ("['klein', 'charm', 'comedy', 'like', 'american', 'pie', 'election', 'deliver', 'one', 'sad', 'action', 'hero', 'performance', 'ever', 'witness']", '-1')
# ("['rare', 'see', 'movie', 'take', 'speedy', 'swan', 'dive', 'promise', 'interest', 'familiar', 'land', 'squarely', 'stupid']", '-1')
# ("['sort', 'dreck', 'usually', 'go', 'straight', 'video', 'lousy', 'script', 'inept', 'direction', 'pathetic', 'acting', 'poorly', 'dub', 'dialogue', 'murky', 'cinematography', 'complete', 'visible', 'boom', 'mike']", '-1')
# ("['direction', 'occasionally', 'rise', 'level', 'marginal', 'competence', 'film', 'hard', 'tell', 'chase']", '-1')
# ("['thing', 'frustrating', 'film', 'buff', 'see', 'otherwise', 'good', 'movie', 'mar', 'beyond', 'redemption', 'disastrous', 'end']", '-1')
# ("['wo', 'harm', 'anyone', 'neither', 'think', 'good', 'reason', 'rush', 'right', 'see', 'probably', 'video', 'store', 'christmas', 'might', 'well', 'suit', 'night', 'living', 'room', 'night', 'movie']", '-1')
# ("['look', 'like', 'video', 'target', 'people', 'like', 'ride', 'bike', 'topless', 'roll', 'mud', 'worthwhile', 'glimpse', 'guide', 'light']", '-1')
# ("['give', 'much', 'time', 'consider', 'looseness', 'piece', 'picture', 'begin', 'resemble', 'shapeless', 'grasp', 'actor', 'workshop']", '-1')
# ("['keep', 'much', 'plot', 'jettison', 'stuff', 'would', 'make', 'move', 'experience', 'people', 'read', 'book']", '-1')
# ("['walk', 'remember', 'shrewd', 'enough', 'activate', 'girlish', 'tear', 'duct', 'mean', 'good', 'enough', 'girl']", '-1')
# ("['carvey', 'character', 'overplayed', 'exaggerated', 'subtlety', 'never', 'trademark']", '-1')
# ("['mildly', 'interesting', 'ponder', 'peculiar', 'american', 'style', 'justice', 'play', 'muddled', 'derivative', 'bother', 'think']", '-1')
# ("['dreadfully', 'earnest', 'inversion', 'concubine', 'love', 'triangle', 'eschew', 'previous', 'film', 'historical', 'panorama', 'roil', 'pathos', 'mugging', 'condescension']", '-1')
# ("['brown', 'saga', 'like', 'many', 'make', 'snappy', 'prose', 'stumblebum', 'movie']", '-1')
# ("['boy', 'sparring', 'like', 'succession', 'blow', 'dump', 'guei', 'wear', 'story', 'cerebral', 'likable', 'plot', 'element']", '-1')
# ("['script', 'vincent', 'r', 'nebrida', 'try', 'cram', 'many', 'ingredient', 'one', 'small', 'pot']", '-1')
# ("['story', 'light', 'sugary', 'macy', 'thanksgiving', 'day', 'parade', 'balloon', 'extra', 'rope', 'would', 'need', 'keep', 'float', 'away']", '-1')
# ("['oedekerk', 'mug', 'mercilessly', 'genuinely', 'funny', 'joke', 'far']", '-1')
# ("['since', 'dahmer', 'resort', 'standard', 'slasher', 'flick', 'thrill', 'mind', 'killer', 'miss', 'major', 'opportunity', 'truly', 'revelatory', 'psyche']", '-1')
# ("['addicted', 'film', 'violence', 'form', 'find', 'anything', 'appreciate']", '-1')
# ("['cold', 'scatter', 'minority', 'report', 'command', 'interest', 'almost', 'solely', 'exercise', 'gorgeous', 'visuals', 'vintage', 'spielberg', 'finally', 'minimally', 'satisfying']", '-1')
# ("['every', 'movie', 'come', 'along', 'remind', 'u', 'bad', 'motion', 'picture', 'truly', 'frank', 'mcklusky', 'c', 'movie']", '-1')
# ("['difficult', 'spot', 'culprit', 'predictable', 'thriller']", '-1')
# ("['soulless', 'stupid', 'sequel']", '-1')
# ("['mostly', 'boring', 'affair', 'confuse', 'sudden', 'finale', 'likely', 'irk', 'viewer']", '-1')
# ("['trapping', 'spy', 'familiar', 'might', 'well', 'watch', 'rerun']", '-1')
# ("['start', 'potentially', 'incredibly', 'twist', 'mystery', 'becomes', 'simply', 'monster', 'chase', 'film']", '-1')
# ("['wake', 'save', 'private', 'ryan', 'black', 'hawk', 'soldier', 'likely', 'heartily', 'sick', 'mayhem', 'cage', 'marine']", '-1')
# ("['messy', 'uncouth', 'incomprehensible', 'vicious', 'absurd']", '-1')
# ("['really', 'feel', 'like', 'short', 'stretch', 'feature', 'length']", '-1')
# ("['hamper', 'paralyze', 'script', 'aim', 'poetry', 'end', 'sound', 'like', 'satire']", '-1')
# ("['cheap', 'vulgar', 'dialogue', 'plot', 'crawl', 'along', 'snail', 'pace']", '-1')
# ("['appreciate', 'theme', 'lawrence', 'tirade', 'knock', 'enjoy', 'big', 'screen', 'postcard', 'martin', 'lawrence', 'lovefest', 'willing', 'crazy']", '-1')
# ("['direct', 'without', 'expected', 'flair', 'imagination', 'hong', 'kong', 'master', 'john', 'woo', 'windtalker', 'air', 'every', 'cliche', 'war', 'movie', 'compendium', 'across', 'indulgent', 'length']", '-1')
# ("['tasteful', 'rock', 'roll', 'movie', 'could', 'put', 'coffee', 'table', 'anywhere']", '-1')
# ("['movie', 'load', 'good', 'intention', 'zeal', 'squeeze', 'action', 'emotion', 'dramatic', 'arc', 'holocaust', 'escape', 'story', 'minac', 'drain', 'movie', 'individuality']", '-1')
# ("['infuriating', 'film', 'think', 'make', 'sense', 'something', 'happen', 'tell', 'sense']", '-1')
# ("['entire', 'movie', 'formulaic', 'forgettable', 'hardly', 'begin', 'fade', 'memory']", '-1')
# ("['setting', 'turn', 'interesting', 'character', 'drama', 'never', 'reach', 'satisfy', 'conclusion']", '-1')
# ("['entertainment', 'destination', 'general', 'public', 'kung', 'pow', 'set', 'new', 'benchmark', 'lameness']", '-1')
# ("['southern', 'nostalgia', 'piece', 'tread', 'line', 'sappy', 'sanguine', 'wind', 'mire', 'quicksand']", '-1')
# ("['pure', 'trash', 'john', 'water', 'movie', 'beat', 'country', 'mile']", '-1')
# ("['wendigo', 'want', 'monster', 'movie', 'crowd', 'fall', 'trap', 'pretention', 'almost', 'every', 'time']", '-1')
# ("['bigelow', 'offer', 'flashy', 'twist', 'turn', 'occasionally', 'fortify', 'turgid', 'fable', 'part', 'weight', 'water', 'come', 'myopic', 'mystery', 'stall', 'lackluster', 'gear', 'emotional', 'blandness']", '-1')
# ("['film', 'big', 'problem', 'laugh']", '-1')
# ("['documentary', 'yiddish', 'theater', 'clan']", '-1')
# ("['chuck', 'norris', 'grenade', 'gag', 'occur', 'time', 'windtalker', 'good', 'indication', 'film']", '-1')
# ("['viewer', 'ask', 'often', 'suspend', 'belief', 'holm', 'performance', 'film', 'would', 'total', 'washout']", '-1')
# ("['exactly', 'worth', 'buck', 'expend', 'full', 'price', 'date', 'come', 'video', 'well', 'worth', 'rental']", '-1')
# ("['ca', 'begin', 'tell', 'tedious', 'resolutely', 'unamusing', 'thoroughly', 'unrewarding', 'reckless', 'squandering', 'four', 'fine', 'act', 'talent']", '-1')
# ("['everybody', 'love', 'david', 'goliath', 'story', 'one', 'tell', 'almost', 'entirely', 'david', 'point', 'view']", '-1')
# ("['throw', 'smoochy', 'train']", '-1')
# ("['eventually', 'showdown', 'sens', 'mushy', 'pea', 'care', 'fire', 'winning', 'shot']", '-1')
# ("['irwin', 'director', 'never', 'come', 'adequate', 'reason', 'pay', 'money', 'get', 'television', 'free']", '-1')
# ("['light', 'engage', 'comedy', 'fumble', 'away', 'almost', 'accumulated', 'enjoyment', 'crucial', 'third', 'act', 'miscalculation']", '-1')
# ("['cedar', 'somewhat', 'defuse', 'provocative', 'theme', 'submerge', 'hoary', 'love', 'triangle']", '-1')
# ("['paraphrase', 'line', 'another', 'dickens', 'novel', 'nicholas', 'nickleby', 'much', 'like', 'fragment', 'underdone', 'potato']", '-1')
# ("['actress', 'may', 'work', 'back', 'story', 'woman', 'portray', 'convincingly', 'viewer', 'get', 'enough', 'background', 'character', 'involve', 'individual', 'rather', 'type']", '-1')
# ("['result', 'however', 'ironically', 'sort', 'disposable', 'homage', 'illustrate', 'whole', 'often', 'less', 'sum', 'part', 'today', 'hollywood']", '-1')
# ("['extremely', 'unpleasant', 'film']", '-1')
# ("['movie', 'friday', 'fan', 'critic', 'damn', 'already', 'like', 'sort', 'thing', 'sort', 'thing']", '-1')
# ("['sincere', 'dramatically', 'conflict', 'gay', 'tale']", '-1')
# ("['wait', 'hit', 'cable']", '-1')
# ("['ultimately', 'feel', 'like', 'one', 'long', 'line', 'film', 'year', 'business', 'make', 'movie']", '-1')
# ("['snoozer']", '-1')
# ("['nothing', 'one', 'relentlessly', 'depress', 'situation', 'another', 'entire', 'running', 'time', 'something', 'could', 'easily', 'deal', 'right', 'life']", '-1')
# ("['minute', 'pokemon', 'may', 'last', 'seem', 'like', 'wish', 'celebi', 'could', 'take', 'back', 'time', 'saw', 'movie', 'could', 'skip']", '-1')
# ("['one', 'problem', 'expecting', 'entire', 'exercise', 'real', 'point']", '-1')
# ("['movie', 'observe', 'rather', 'one', 'enter']", '-1')
# ("['least', 'moore', 'real', 'charmer']", '-1')
# ("['john', 'carlen', 'script', 'full', 'unhappy', 'character', 'anything', 'compelling']", '-1')
# ("['labute', 'ca', 'avoid', 'fatal', 'mistake', 'modern', 'era', 'change', 'male', 'academic', 'brit', 'american', 'choice', 'upset', 'novel', 'exquisite', 'balance', 'shred', 'fabric', 'film']", '-1')
# ("['notion', 'delete', 'emotion', 'people', 'even', 'advanced', 'prozac', 'nation', 'insanely', 'dysfunctional', 'rampantly', 'design', 'equilibrium', 'become', 'concept', 'doofus']", '-1')
# ("['stale', 'first', 'act', 'scrooge', 'story', 'blatant', 'product', 'placement', 'good', 'comedic', 'song', 'strong', 'finish', 'dumb', 'fart', 'joke']", '-1')
# ("['unsurprisingly', 'way', 'work', 'make', 'woman', 'look', 'like', 'stereotypical', 'caretaker', 'moral', 'teacher', 'instead', 'serious', 'athlete']", '-1')
# ("['film', 'lose', 'sight', 'story']", '-1')
# ("['adam', 'sandler', 'eight', 'crazy', 'night', 'grows', 'like', 'rash']", '-1')
# ("['scooby', 'make', 'silly', 'original', 'cartoon', 'seem', 'smart', 'comparison']", '-1')
# ("['increasingly', 'event', 'neil', 'burger', 'follow', 'terribly', 'convince', 'pity', 'consider', 'barry', 'terrific', 'performance']", '-1')
# ("['get', 'well', 'foster', 'leaf', 'little', 'room']", '-1')
# ("['movie', 'pad', 'allen', 'jelly', 'belly']", '-1')
# ("['resident', 'evil', 'product', 'cinematic', 'predecessor', 'much', 'mtv', 'sugar', 'hysteria', 'playstation', 'cocktail']", '-1')
# ("['rather', 'average', 'action', 'film', 'benefit', 'several', 'funny', 'moment', 'supply', 'epps']", '-1')
# ("['unspeakably', 'unbearably', 'dull', 'feature', 'ream', 'flatly', 'deliver', 'dialogue', 'heroine', 'come', 'across', 'shallow']", '-1')
# ("['resembles', 'soft', 'porn', 'brian', 'de', 'palma', 'pastiche']", '-1')
# ("['bluto', 'blutarsky', 'miss']", '-1')
# ("['innocuous', 'enough', 'make', 'even', 'van', 'damme', 'look', 'good']", '-1')
# ("['glorified', 'sitcom', 'long', 'unfunny', 'one']", '-1')
# ("['woody', 'allen', 'write', 'deliver', 'one', 'liner', 'well', 'anybody', 'lot', 'problem', 'movie']", '-1')
# ("['execrable']", '-1')
# ("['devoid', 'quality', 'make', 'first', 'film', 'special']", '-1')
# ("['movie', 'long', 'city', 'sea', 'swing', 'one', 'approach', 'end', 'stay', 'formula', 'waste', 'de', 'niro', 'mcdormand', 'good', 'actor', 'cast']", '-1')
# ("['plotless', 'collection', 'moronic', 'stunt', 'far', 'bad', 'movie', 'year']", '-1')
# ("['however', 'sincere', 'may', 'rise', 'place', 'never', 'quite', 'justify', 'existence']", '-1')
# ("['parker', 'update', 'setting', 'attempt', 'make', 'film', 'relevant', 'today', 'without', 'fully', 'understand', 'make', 'story', 'relevant', 'first', 'place']", '-1')
# ("['sort', 'century', 'morality', 'play', 'latino', 'hip', 'hop', 'beat', 'second', 'half', 'movie', 'really', 'go', 'downhill']", '-1')
# ("['paxton', 'uneven', 'directorial', 'debut', 'fail', 'unlock', 'full', 'potential', 'many', 'way', 'fresh', 'dramatically', 'substantial', 'spin', 'genre']", '-1')
# ("['script', 'become', 'lifeless', 'fall', 'apart', 'like', 'cheap', 'lawn', 'chair']", '-1')
# ("['script', 'fall', 'back', 'many', 'shenanigan', 'hardly', 'distinguish', 'next', 'teen', 'comedy']", '-1')
# ("['film', 'start', 'promisingly', 'end', 'predictable', 'far', 'cliched', 'really', 'work']", '-1')
# ("['let', 'issue', 'moratorium', 'effective', 'immediately', 'treacly', 'film', 'inspirational', 'professor', 'child', 'heartwarmingly', 'motivate']", '-1')
# ("['element', 'condescension', 'filmmaker', 'look', 'subject', 'lofty', 'perch', 'finally', 'make', 'sex', 'stranger', 'open', 'today', 'new', 'york', 'metropolitan', 'area', 'distasteful']", '-1')
# ("['alternately', 'frustrating', 'rewarding']", '-1')
# ("['impossible', 'even', 'categorize', 'smutty', 'guilty', 'pleasure']", '-1')
# ("['despite', 'suffer', 'failure', 'man', 'write', 'rocky', 'deserve', 'go', 'ship', 'leaky']", '-1')
# ("['swinging', 'film', 'make', 'seem', 'hobby', 'attract', 'young', 'fit', 'intelligent']", '-1')
# ("['memorable', 'moment', 'green', 'throw', 'medical', 'equipment', 'window', 'particularly', 'funny', 'serious', 'urge', 'grab', 'old', 'lady', 'end', 'aisle', 'walker', 'toss', 'screen', 'frustration']", '-1')
# ("['see', 'clockstoppers', 'nothing', 'well', 'minute', 'warn', 'may', 'feel', 'time', 'decide', 'stand', 'still', 'battery', 'watch', 'die']", '-1')
# ("['suffers', 'since', 'british', 'filmmaker', 'monty', 'formula', 'mercilessly', 'since']", '-1')
# ("['enough', 'throwaway', 'reference', 'faith', 'rainbows', 'plant', 'face', 'segment', 'populace', 'make', 'walk', 'remember', 'niche', 'hit']", '-1')
# ("['yes', 'give', 'movie', 'rating', 'zero', 'fan', 'show', 'consider', 'dis', 'consider']", '-1')
# ("['cumulative', 'effect', 'movie', 'repulsive', 'depressing']", '-1')
# ("['child', 'adult', 'enamor', 'thing', 'pokemon', 'wo', 'disappoint']", '-1')
# ("['even', 'care', 'plot', 'antonio', 'liu', 'faceoff', 'still', 'terrible']", '-1')
# ("['child', 'century', 'though', 'well', 'dress', 'well', 'make', 'ultimately', 'fall', 'prey', 'contradiction', 'afflict', 'many', 'movie', 'writer']", '-1')
# ("['much', 'movie', 'joint', 'promotion', 'national', 'basketball', 'association', 'teenaged', 'rap', 'adolescent', 'lil', 'bow', 'wow']", '-1')
# ("['peralta', 'mythmaking', 'could', 'use', 'informed', 'adult', 'hindsight']", '-1')
# ("['amazingly', 'dopey']", '-1')
# ("['espionage', 'thriller', 'misfortune', 'release', 'decade', 'late']", '-1')
# ("['cloak', 'familiar', 'equation', 'career', 'kid', 'misery', 'tiresome', 'dud']", '-1')
# ("['good', 'girl', 'film', 'talent', 'undeniable', 'result', 'underwhelming']", '-1')
# ("['collection', 'whatever', 'fills', 'time', 'unified', 'whole']", '-1')
# ("['animation', 'game', 'phenomenon', 'peak', 'three', 'year', 'ago', 'actually', 'die', 'slow', 'death', 'poor', 'quality', 'pokemon', 'ever', 'indication']", '-1')
# ("['sexy', 'dangerous', 'actress', 'role', 'remind', 'every', 'turn', 'elizabeth', 'berkley', 'flopping']", '-1')
# ("['kid', 'thornberry', 'stuff', 'probably', 'wedgie', 'heaven', 'anyone', 'else', 'may', 'whatever', 'reason', 'think', 'go', 'see', 'movie', 'hereby', 'give', 'fair', 'warning']", '-1')
# ...
# ("['seem', 'like', 'strange', 'route', 'true', 'love', 'maybe', 'film', 'maker', 'credit', 'believe', 'exactly', 'two', 'people', 'need', 'find']", '1')
# ("['film', 'vision', 'sport', 'secular', 'religion', 'bit', 'cloying', 'family', 'community', 'hearten', 'way', 'season', 'mark', 'new', 'start']", '1')
# ("['one', 'best', 'grow', 'strain', 'dare', 'film', 'argue', 'sexual', 'relationship', 'hurt', 'anyone', 'work', 'participant', 'relationship', 'worthy', 'respect']", '1')
# ("['adorably', 'whimsical', 'comedy', 'deserve', 'passing', 'twinkle']", '1')
# ("['engross', 'story', 'combine', 'psychological', 'drama', 'sociological', 'reflection', 'thriller']", '1')
# ("['easy', 'cynical', 'documentary', 'underdogs', 'beat', 'odds', 'human', 'spirit', 'triumph', 'westbrook', 'foundation', 'dalrymple', 'film', 'earn', 'uplift']", '1')
# ("['mel', 'gibson', 'fight', 'good', 'fight', 'vietnam', 'director', 'randall', 'wallace', 'war', 'flick', 'core', 'decency']", '1')
# ("['real', 'visual', 'charge', 'filmmaking', 'strong', 'erotic', 'spark', 'crucial', 'sequence']", '1')
# ("['brutal', 'funny', 'work', 'nicole', 'holofcenter', 'insightful', 'responsible', 'illuminating', 'comedy', 'wrap', 'proceeding', 'neatly', 'idea', 'tie', 'together', 'beautifully']", '1')
# ("['film', 'blunt', 'indictment', 'part', 'perhaps', 'surreal', 'campaign', 'bring', 'kissinger', 'trial', 'crime', 'humanity']", '1')
# ("['one', 'important', 'exhilarating', 'form', 'animated', 'filmmaking', 'since', 'old', 'walt', 'doodle', 'steamboat', 'willie']", '1')
# ("['move', 'bond', 'girl', 'deserve', 'sequel']", '1')
# ("['kind', 'trifle', 'date', 'night', 'invent']", '1')
# ("['testament', 'film', 'considerable', 'charm', 'succeed', 'entertain', 'despite', 'play', 'like', 'sitcom', 'replete', 'stereotypical', 'familial', 'quandary', 'sheer', 'unbridled', 'delight', 'way', 'story', 'unfurls']", '1')
# ("['tell', 'story', 'atmospheric', 'ballast', 'shrug', 'plot', 'persnickety', 'problem', 'simply', 'matter', 'shrugging', 'mood']", '1')
# ("['film', 'hard', 'dismiss', 'moody', 'thoughtful', 'lit', 'flash', 'mordant', 'humor']", '1')
# ("['man', 'elysian', 'field', 'doom', 'smallness', 'also', 'elevate', 'kind', 'movie', 'enjoy', 'one', 'lucky', 'seek']", '1')
# ("['emerge', 'unsettling', 'picture', 'childhood', 'innocence', 'combine', 'indoctrinated', 'prejudice', 'promise', 'compelling', 'piece', 'demonstrate', 'well', 'child', 'train', 'live', 'carry', 'parent', 'anguish']", '1')
# ("['meticulously', 'uncover', 'trail', 'outrageous', 'force', 'craven', 'concealment']", '1')
# ("['hey', 'happy', 'many', 'thing', 'stone', 'midnight', 'flick', 'deconstruction', 'gay', 'fantasia', 'love', 'story', 'sanguine', 'title']", '1')
# ("['wo', 'look', 'religious', 'fanatic', 'backyard', 'shed', 'way']", '1')
# ("['best', 'festival', 'cannes', 'bubble', 'excitement', 'festival', 'cannes']", '1')
# ("['general', 'air', 'exuberance', 'benjamin', 'hard', 'resist']", '1')
# ("['lovably', 'hollywood', 'confection']", '1')
# ("['happy', 'see', 'alternate', 'version', 'ultimate', 'exercise', 'view', 'deleted', 'scene']", '1')
# ("['turn', 'grip', 'amuse', 'tender', 'earmark', 'french', 'cinema', 'best']", '1')
# ("['warning', 'resist', 'temptation', 'film', 'blunt', 'challenging', 'offer', 'easy', 'reward', 'stay', 'clean']", '1')
# ("['wonder', 'wonder', 'teen', 'movie', 'humanistic', 'message']", '1')
# ("['quirky', 'comedy', 'set', 'newfoundland', 'cleverly', 'capture', 'dry', 'wit', 'prevalent', 'rock']", '1')
# ("['pepper', 'witty', 'dialogue', 'inventive', 'moment']", '1')
# ("['rather', 'watch', 'rerun', 'powerpuff', 'girl']", '1')
# ("['prospect', 'film', 'like', 'kangaroo', 'jack', 'burst', 'across', 'america', 'winter', 'movie', 'screen', 'pleasure', 'film', 'like', 'hour', 'alternative']", '1')
# ("['wonderful', 'combination', 'sweetness', 'extraordinary', 'technical', 'accomplishment', 'first', 'film', 'maintain', 'overall', 'impact', 'fall', 'little', 'flat', 'storyline', 'never', 'quite', 'deliver', 'original', 'magic']", '1')
# ("['like', 'title', 'character', 'nicholas', 'nickleby', 'find', 'reduced', 'circumstance', 'also', 'like', 'hero', 'remain', 'brightly', 'optimistic', 'come', 'end']", '1')
# ("['thoughtful', 'unflinching', 'examination', 'alternative', 'lifestyle', 'sex', 'stranger', 'success']", '1')
# ("['unpretentious', 'charm', 'quirky', 'original']", '1')
# ("['spin', 'web', 'dazzle', 'entertainment', 'may', 'overstate', 'certainly', 'deliver', 'good']", '1')
# ("['slightly', 'flaw', 'fairly', 'unbelievable', 'finale', 'everything', 'else', 'top', 'shelf']", '1')
# ("['fascinating', 'look', 'israel', 'ferment', 'feel', 'immediate', 'late', 'news', 'footage', 'gaza', 'heighten', 'drama', 'twice', 'powerful']", '1')
# ("['manages', 'delight', 'without', 'much', 'story']", '1')
# ("['denying', 'burn', 'filmmaker', 'bright', 'future', 'ahead']", '1')
# ("['confession', 'make', 'particularly', 'like', 'e', 'first', 'time', 'saw', 'young', 'boy', 'damn', 'also', 'want', 'little', 'alien', 'friend']", '1')
# ("['formula', 'serve', 'paper', 'skeleton', 'good', 'acting', 'dialogue', 'comedy', 'direction', 'especially', 'charm']", '1')
# ("['genuinely', 'funny', 'ensemble', 'comedy', 'also', 'ask', 'audience', 'heartwarming', 'nonjudgmental', 'kind', 'way', 'consider', 'value', 'daily', 'life']", '1')
# ("['though', 'aboriginal', 'aspect', 'lend', 'end', 'extraordinary', 'poignancy', 'story', 'could', 'play', 'working', 'class', 'community', 'nation']", '1')
# ("['energetic', 'engaging', 'film', 'never', 'pretend', 'something']", '1')
# ("['violent', 'initiation', 'rite', 'audience', 'much', 'angelique', 'opening', 'dance', 'guarantee', 'karmen', 'enthronement', 'among', 'cinema', 'memorable', 'woman']", '1')
# ("['animation', 'landmark', 'monumental', 'disney', 'breakthrough', 'snow', 'white', 'seven', 'dwarf']", '1')
# ("['entertaining', 'ultimately', 'minor', 'thriller']", '1')
# ("['sex', 'stranger', 'fascinate']", '1')
# ("['subtle', 'poignant', 'picture', 'goodness', 'flaw', 'compromise', 'sad']", '1')
# ("['wry', 'affectionate', 'delight']", '1')
# ("['acting', 'pauline', 'paulette', 'good', 'round', 'really', 'set', 'film', 'apart', 'debrauwer', 'refusal', 'push', 'easy', 'emotional', 'button']", '1')
# ("['one', 'joyous', 'film', 'leap', 'national', 'boundary', 'celebrates', 'universal', 'human', 'nature']", '1')
# ("['penetrating', 'glimpse', 'ego', 'comic']", '1')
# ("['kid', 'stirring', 'time', 'beautifully', 'draw', 'movie', 'adult', 'least', 'dream', 'image', 'west', 'savor', 'whenever', 'film', 'lamer', 'instinct', 'saddle']", '1')
# ("['pay', 'full', 'remarkably', 'engage', 'despite', 'noticeably', 'derivative', 'goodfellas', 'least', 'half', 'dozen', 'flick']", '1')
# ("['less', 'cinematically', 'powerful', 'quietly', 'deeply', 'move', 'powerful']", '1')
# ("['waydowntown', 'manages', 'nail', 'ennui', 'denuded', 'urban', 'living', 'without', 'give']", '1')
# ("['story', 'potential', 'touch', 'angel', 'simplicity', 'sappiness', 'thirteen', 'conversation', 'one', 'thing', 'generosity', 'optimism', 'never', 'resort', 'easy', 'sentiment']", '1')
# ("['borstal', 'boy', 'especially', 'realistic', 'engage', 'nostalgia', 'piece']", '1')
# ("['often', 'demented', 'good', 'way', 'uneven', 'film', 'part']", '1')
# ("['script', 'snazzy', 'dialogue', 'establish', 'realistic', 'atmosphere', 'involve', 'u', 'unfolding', 'crisis', 'lazy', 'plotting', 'ensure', 'little', 'emotional', 'investment', 'pay']", '1')
# ("['maggie', 'smith', 'member', 'absolutely', 'crack', 'crass', 'gasp', 'gas', 'verbal', 'deportment']", '1')
# ("['movie', 'refresh', 'mind', 'spirit', 'along', 'body', 'original', 'content', 'look', 'style']", '1')
# ("['although', 'hate', 'one', 'good', 'either', 'safely', 'recommend', 'babysitter']", '1')
# ("['another', 'best', 'year', 'selection']", '1')
# ("['film', 'gloss', 'jolt', 'expect', 'de', 'palma', 'make', 'transport', 'also', 'one', 'smart', 'pleasurable', 'expression', 'pure', 'movie', 'love', 'come', 'american', 'director', 'year']", '1')
# ("['valuable', 'film']", '1')
# ("['max', 'poke', 'provokes', 'take', 'expressionistic', 'license', 'hit', 'nerve', 'far', 'art', 'concern', 'mission', 'accomplish']", '1')
# ("['literary', 'purist', 'may', 'please', 'far', 'mainstream', 'entertainment', 'go', 'job', 'please', 'crowd']", '1')
# ("['polanski', 'look', 'back', 'place', 'saw', 'childhood', 'capture', 'free', 'artefact', 'show', 'heartbreakingly', 'drably']", '1')
# ("['intriguing', 'stylish']", '1')
# ("['story', 'mostly', 'tell', 'interview', 'several', 'survivor', 'whose', 'rivet', 'memory', 'render', 'clarity', 'happen', 'yesterday']", '1')
# ("['compelling', 'story', 'musical', 'passion', 'governmental', 'odds']", '1')
# ("['ichi', 'killer', 'takashi', 'miike', 'japan', 'wild', 'filmmaker', 'give', 'u', 'crime', 'fighter', 'carry', 'emotional', 'baggage', 'batman']", '1')
# ("['never', 'know', 'change', 'lane', 'go', 'take', 'heck', 'ride', 'samuel', 'l', 'jackson', 'one', 'best', 'actor']", '1')
# ("['breheny', 'lensing', 'new', 'zealand', 'cook', 'island', 'location', 'capture', 'beauty', 'land', 'people']", '1')
# ("['almost', 'unbearably', 'morbid', 'love', 'story']", '1')
# ("['wild', 'thornberrys', 'movie', 'sibling', 'rivalry', 'general', 'family', 'chaos', 'anyone', 'relate']", '1')
# ("['forceful', 'drama', 'alienated', 'executive']", '1')
# ("['spielberg', 'realization', 'america', 'masterful', 'make', 'minority', 'report', 'necessary', 'view', 'fan', 'film', 'best', 'special', 'effect', 'ever']", '1')
# ("['gag', 'fly', 'furiously', 'funny', 'pace', 'rip', 'aware', 'one', 'felt', 'movie', 'end', 'damned', 'soon']", '1')
# ("['best', 'film', 'year']", '1')
# ("['enthralling', 'entertaining', 'feature']", '1')
# ("['strip', 'almost', 'entirely', 'tool', 'nudity', 'profanity', 'violence', 'labute', 'manage', 'make', 'point', 'modern', 'man', 'problematic', 'quest', 'human', 'connection']", '1')
# ("['remarkable', 'movie', 'unsatisfying', 'end', 'point']", '1')
# ("['brown', 'sugar', 'satisfy', 'romantic', 'comedy', 'charming', 'well', 'act', 'guarantee', 'leave', 'theater', 'smile', 'face']", '1')
# ("['smith', 'find', 'amuse', 'juxtaposition', 'justify', 'exercise']", '1')
# ("['work', 'surprisingly', 'sensitive', 'script', 'gianni', 'romoli', 'ozpetek', 'avoids', 'pitfall', 'expect', 'potentially', 'sudsy']", '1')
# ("['old', 'cad', 'instruct', 'young', 'lad', 'zen', 'art', 'get', 'lay', 'prickly', 'indie', 'comedy', 'manner', 'misanthropy']", '1')
# ("['austin', 'power', 'goldmember', 'right', 'stuff', 'silly', 'summer', 'entertainment', 'enough', 'laugh', 'sustain', 'interest', 'end']", '1')
# ("['one', 'jaglom', 'better', 'effort', 'wry', 'sometime', 'bitter', 'movie', 'love']", '1')
# ("['schaeffer', 'film', 'may', 'work', 'well']", '1')
# ("['fresh', 'entertaining', 'comedy', 'look', 'relationship', 'minus', 'traditional', 'gender', 'role']", '1')
# ("['although', 'estela', 'bravo', 'documentary', 'cloyingly', 'hagiographic', 'portrait', 'cuban', 'leader', 'fidel', 'castro', 'still', 'guilty', 'pleasure', 'watch']", '1')
# ("['surprisingly', 'film', 'hilarious', 'adventure', 'shamelessly', 'enjoy']", '1')
# ("['way', 'home', 'ode', 'unconditional', 'love', 'compassion', 'garner', 'year', 'see', 'condition', 'old', 'privy', 'often', 'misconstrue', 'weakness']", '1')
# ("['brutally', 'honest', 'tell', 'humor', 'poignancy', 'make', 'message', 'resonate']", '1')
# ("['read', 'subtitle', 'opera', 'sing', 'italian', 'like', 'theatre', 'type', 'costume', 'enjoy', 'movie']", '1')
# ("['pretty', 'funny', 'movie', 'humor', 'come', 'incongruous', 'chemically', 'perfect', 'teaming', 'crystal', 'de', 'niro']", '1')
# ("['gangster', 'solid', 'satisfy', 'fare', 'adult']", '1')
# ("['chicago', 'hugely', 'imaginative', 'successful', 'casting', 'great', 'credit', 'well', 'one', 'terrific', 'score', 'attitude', 'spare']", '1')
# ("['enough', 'gun', 'battle', 'throwaway', 'humor', 'cover', 'yawning', 'chasm', 'plot']", '1')
# ("['jerky', 'camera', 'documentary', 'feel', 'bloody', 'sunday', 'sobering', 'recount', 'bleak', 'day', 'derry']", '1')
# ("['likely', 'prefer', 'keep', 'watching']", '1')
# ("['insomnia', 'lose', 'point', 'surrender', 'formulaic', 'scene', 'conclusion', 'performance', 'pacino', 'williams', 'swank', 'keep', 'viewer', 'way']", '1')
# ("['might', 'readily', 'dismiss', 'tiresome', 'rant', 'age', 'filmmaker', 'still', 'thumb', 'nose', 'convention', 'take', 'surprising', 'subtle', 'turn', 'midway', 'point']", '1')
# ("['time', 'commercialism', 'squeeze', 'life', 'whatever', 'idealism', 'american', 'moviemaking', 'ever', 'godfrey', 'reggio', 'career', 'shine', 'like', 'lonely', 'beacon']", '1')
# ("['inuit', 'masterpiece', 'give', 'goosebumps', 'uncanny', 'tale', 'love', 'communal', 'discord', 'justice', 'unfolds']", '1')
# ("['popcorn', 'movie', 'fun', 'equal', 'dos', 'action', 'cheese', 'ham', 'cheek', 'well', 'serious', 'debt', 'road', 'warrior', 'feel', 'like', 'unrealized', 'potential']", '1')
# ("['testament', 'de', 'niro', 'director', 'michael', 'movie', 'end', 'accept', 'character', 'film', 'flaw']", '1')
# ("['performance', 'potent', 'woman', 'story', 'ably', 'intercut', 'involve']", '1')
# ("['enormously', 'entertaining', 'movie', 'like', 'nothing', 'ever', 'see', 'yet', 'completely', 'familiar']", '1')
# ("['lan', 'yu', 'genuine', 'love', 'story', 'full', 'traditional', 'layer', 'awaken', 'ripen', 'separation', 'recovery']", '1')
# ("['child', 'occupy', 'minute']", '1')
# ("['pull', 'rare', 'trick', 'recreate', 'look', 'certain', 'era', 'also', 'feel']", '1')
# ("['twohy', 'good', 'ultimately', 'story', 'compels']", '1')
# ("['maguire', 'poster', 'boy', 'geek', 'generation']", '1')
# ("['sweetly', 'affect', 'story', 'four', 'sister', 'cop', 'one', 'way', 'another', 'life', 'endgame']", '1')
# ("['passion', 'melodrama', 'sorrow', 'laugther', 'tear', 'cascade', 'screen', 'effortlessly']", '1')
# ("['road', 'perdition', 'display', 'greatness', 'worth', 'see', 'also', 'come', 'laziness', 'arrogance', 'thing', 'already', 'know']", '1')
# ("['marvelous', 'performance', 'allison', 'lohman', 'foster', 'child']", '1')
# ("['arliss', 'howard', 'ambitious', 'move', 'adventurous', 'directorial', 'debut', 'big', 'bad', 'love', 'meet', 'many', 'challenge', 'pose', 'one', 'forgive', 'film', 'flaw']", '1')
# ("['critic', 'need', 'good', 'laugh', 'rendition', 'notorious', 'mtv', 'show', 'deliver', 'outrageous', 'sicken', 'sidesplitting', 'good', 'steaming', 'visceral', 'heap']", '1')
# ("['dumb', 'fun', 'curiously', 'adolescent', 'movie']", '1')
# ("['many', 'insightful', 'moment']", '1')
# ("['charm', 'lead', 'performance', 'allow', 'u', 'forget', 'film', 'problem']", '1')
# ("['vivid', 'sometimes', 'surreal', 'glimpse', 'mystery', 'human', 'behavior']", '1')
# ("['tour', 'de', 'force', 'modern', 'cinema']", '1')
# ("['peralta', 'capture', 'luminous', 'interview', 'amazingly', 'evocative', 'film', 'three', 'decade', 'ago', 'essence', 'dogtown', 'experience']", '1')
# ("['lively', 'appeal', 'last', 'kiss', 'lie', 'ease', 'integrate', 'thoughtfulness', 'comedy']", '1')
# ("['without', 'resort', 'camp', 'parody', 'haynes', 'like', 'sirk', 'differently', 'transform', 'rhetoric', 'hollywood', 'melodrama', 'something', 'provocative', 'rich', 'strange']", '1')
# ("['performance', 'absolute', 'joy']", '1')
# ("['french', 'filmmaker', 'karim', 'dridi', 'celebrate', 'hardy', 'spirit', 'cuban', 'music']", '1')
# ("['grant', 'carry', 'day', 'impeccable', 'comic', 'timing', 'raffish', 'charm', 'pierce', 'intellect']", '1')
# ("['sensitive', 'astute', 'first', 'feature', 'birot']", '1')
# ("['exuberantly', 'romantic', 'serenely', 'melancholy', 'time', 'may', 'prove', 'tsai', 'masterpiece']", '1')
# ("['mazel', 'tov', 'film', 'family', 'joyous', 'life', 'act', 'yiddish', 'stage']", '1')
# ("['stand', 'shadow', 'motown', 'best', 'kind', 'documentary', 'one', 'make', 'deplete', 'yesterday', 'feel', 'much', 'like', 'tomorrow']", '1')
# ("['nice', 'see', 'piscopo', 'year', 'chaykin', 'headly', 'priceless']", '1')
# ("['provide', 'porthole', 'noble', 'tremble', 'incoherence', 'define', 'u']", '1')

# %%
#split test and training set
Train_X, Test_X, Train_Y, Test_Y = model_selection.train_test_split(corpus['final_text'],corpus['label'],test_size=0.3)

# %%
sum([1 for i in Test_Y if i == '-1'])
# Out:
# 1580

# %%
Encoder = LabelEncoder()
Train_Y = Encoder.fit_transform(Train_Y)
Test_Y = Encoder.fit_transform(Test_Y)

# %%
print (Test_Y)
Tfidf_vect = TfidfVectorizer(max_features=10000)
Tfidf_vect.fit(corpus['final_text'])
Train_X_Tfidf = Tfidf_vect.transform(Train_X)
Test_X_Tfidf = Tfidf_vect.transform(Test_X)
print(Tfidf_vect.vocabulary_)
# Out:
# [0 0 1 ... 1 0 0]
# {'simplistic': 7178, 'silly': 7163, 'tedious': 8305, 'juvenile': 4018, 'teenage': 8311, 'boy': 834, 'could': 1587, 'possibly': 5526, 'find': 2764, 'funny': 2984, 'exploitative': 2585, 'largely': 4141, 'devoid': 1955, 'depth': 1902, 'sophistication': 7494, 'would': 9866, 'make': 4423, 'watching': 9572, 'graphic': 3168, 'treatment': 8732, 'crime': 1652, 'bearable': 604, 'discard': 2022, 'potential': 5537, 'study': 7881, 'instead': 3774, 'skewed': 7239, 'melodrama': 4561, 'circumstantial': 1241, 'situation': 7220, 'visually': 9456, 'flashy': 2797, 'narratively': 4851, 'opaque': 5070, 'emotionally': 2335, 'vapid': 9296, 'exercise': 2548, 'style': 7909, 'story': 7821, 'also': 220, 'unoriginal': 9110, 'come': 1368, 'already': 219, 'recycle': 6002, 'time': 8527, 'care': 1051, 'count': 1589, 'thing': 8438, 'give': 3076, 'movie': 4771, 'point': 5471, 'bravado': 849, 'take': 8210, 'entirely': 2417, 'stale': 7711, 'concept': 1443, 'push': 5744, 'audience': 472, 'meat': 4539, 'grinder': 3203, 'one': 5062, 'much': 4780, 'farcical': 2671, 'sour': 7523, 'unfortunately': 9026, 'actor': 73, 'serve': 6944, 'hack': 3255, 'script': 6797, 'disquieting': 2057, 'relatively': 6103, 'allusion': 208, 'serial': 6933, 'murder': 4797, 'fall': 2647, 'attempt': 460, 'humanize': 3506, 'subject': 7930, 'sentimental': 6911, 'mess': 4592, 'never': 4909, 'ring': 6394, 'true': 8785, 'performance': 5315, 'often': 5048, 'engaging': 2375, 'loose': 4334, 'collection': 1349, 'improvised': 3630, 'number': 4996, 'probably': 5627, 'work': 9842, 'well': 9639, 'tv': 8841, 'documentary': 2098, 'interesting': 3815, 'compelling': 1403, 'cutting': 1722, 'room': 6453, 'floor': 2825, 'somewhere': 7476, 'lie': 4242, 'footage': 2856, 'might': 4624, 'trenchant': 8741, 'ironic': 3875, 'cultural': 1698, 'satire': 6643, 'frustrating': 2964, 'misfire': 4666, 'ensemble': 2398, 'player': 5429, 'gain': 3000, 'notice': 4976, 'guy': 3250, 'ritchie': 6409, 'lock': 4311, 'stock': 7798, 'two': 8853, 'smoking': 7364, 'barrel': 575, 'snatch': 7385, 'unlikely': 9087, 'become': 614, 'household': 3488, 'name': 4841, 'basis': 588, 'first': 2775, 'starring': 7741, 'vehicle': 9323, 'difference': 1980, 'courage': 1596, 'go': 3108, 'top': 8607, 'stupid': 7898, 'nothing': 4975, 'seem': 6856, 'analyze': 266, 'even': 2488, 'joe': 3964, 'viterelli': 9461, 'de': 1781, 'niro': 4940, 'master': 4497, 'screenwriting': 6791, 'john': 3966, 'yale': 9908, 'previously': 5601, 'skull': 7259, 'last': 4147, 'year': 9922, 'rollerball': 6439, 'enough': 2396, 'say': 6674, 'except': 2527, 'film': 2753, 'overboard': 5138, 'common': 1388, 'sense': 6900, 'fly': 2840, 'window': 9753, 'along': 215, 'hail': 3257, 'bullet': 940, 'none': 4952, 'ever': 2494, 'hit': 3423, 'sascha': 6636, 'minute': 4650, 'decent': 1800, 'material': 4503, 'execution': 2545, 'pedestrian': 5283, 'positive': 5520, 'comment': 1380, 'rob': 6420, 'schneider': 6732, 'actually': 77, 'turn': 8831, 'pretty': 5595, 'convincing': 1553, 'girl': 3074, 'remake': 6131, 'pale': 5190, 'imitation': 3583, 'show': 7090, 'studio': 7879, 'firmly': 2774, 'believe': 641, 'people': 5302, 'lose': 4341, 'ability': 8, 'think': 8439, 'forgive': 2875, 'shoddy': 7067, 'product': 5641, 'long': 4324, 'little': 4295, 'action': 70, 'farce': 2670, 'parody': 5224, 'comedy': 1372, 'premise': 5580, 'comparison': 1398, 'reality': 5927, 'commentary': 1381, 'knowledge': 4087, 'exciting': 2537, 'exoticism': 2561, 'sound': 7519, 'typical': 8857, 'viewer': 9408, 'rest': 6256, 'lull': 4368, 'coma': 1363, 'party': 5236, 'scene': 6706, 'deliver': 1856, 'tawdry': 8274, 'kick': 4047, 'culture': 1699, 'head': 3335, 'toilet': 8574, 'ferocity': 2724, 'frozen': 2961, 'tequila': 8365, 'know': 4085, 'see': 6851, 'criticism': 1663, 'rise': 6406, 'easy': 2245, 'cynical': 1727, 'potshot': 5539, 'morally': 4735, 'bankrupt': 558, 'character': 1133, 'construction': 1508, 'feel': 2710, 'less': 4216, 'loving': 4354, 'integrated': 3792, 'homage': 3446, 'like': 4259, 'mere': 4583, 'excuse': 2543, 'wan': 9531, 'thinly' ...

# %%
# fit the training dataset on the NB classifier
Naive = naive_bayes.MultinomialNB()
Naive.fit(Train_X_Tfidf,Train_Y)
# predict the labels on validation dataset
predictions_NB = Naive.predict(Test_X_Tfidf)
# Use accuracy_score function to get the accuracy
print("Naive Bayes Accuracy Score -> ",accuracy_score(predictions_NB, Test_Y)*100)
# Out:
# Naive Bayes Accuracy Score ->  76.05501719287278

# %%
# Classifier - Algorithm - SVM
# fit the training dataset on the classifier
SVM = svm.SVC(C=1.0, kernel='linear', degree=3, gamma='auto')
SVM.fit(Train_X_Tfidf,Train_Y)
# predict the labels on validation dataset
predictions_SVM = SVM.predict(Test_X_Tfidf)
# Use accuracy_score function to get the accuracy
print("SVM Accuracy Score -> ",accuracy_score(predictions_SVM, Test_Y)*100)
# Out:
# SVM Accuracy Score ->  74.3044701469209
